# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


n = [] #name
y = []#year
r = [] #rank
cf = []#certificate
dr = []#duration
g = []#genre
rate = []#rating
desc = []#description


page = requests.get("https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&ref_=adv_prv")

soup = BeautifulSoup(page.content,'html.parser')

a = soup.find_all('div',class_='lister-item mode-advanced')


content = a[0].find('div',class_='lister-item-content')
text = content.find('a')


year = content.find('span',class_='lister-item-year text-muted unbold')
year = year.text.replace('(',"").replace(")","")
rank = content.find('span',class_='lister-item-index unbold text-primary')

d = content.find('p',class_="text-muted")
certificate = d.find('span',class_='certificate')
duration = d.find('span',class_='runtime')
genre=d.find('span',class_='genre')

rating = content.find('strong')



c =content.find_all('p',class_='text-muted')
description = c[1].text

print(description)







#print(text.text,year,rank.text,certificate.text,duration.text,genre.text)
# Out:
#     Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.

# %%
n = [] #name
y = []#year
r = [] #rank
cf = []#certificate
dr = []#duration
g = []#genre
rate = []#rating
desc = []#description

links = [
    'https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&ref_=adv_prv',
    'https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=51&ref_=adv_nxt',
    'https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=101&ref_=adv_nxt',
    'https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=151&ref_=adv_nxt',
    'https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=201&ref_=adv_nxt'
]

page = requests.get("https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&ref_=adv_prv")
soup = BeautifulSoup(page.content,'html.parser')

a = soup.find_all('div',class_='lister-item mode-advanced')
for i in range(len(a)):
    
    
    content = a[i].find('div',class_='lister-item-content')
    
    
    text = content.find('a')
    n.append(text.text)
    
    year = content.find('span',class_='lister-item-year text-muted unbold')
    year = year.text.replace('(',"").replace(")","")
    y.append(year)
    rank = content.find('span',class_='lister-item-index unbold text-primary')
    rank = rank.text.replace('.',"")
    r.append(rank)
    
    print(text.text,year,rank)
    
    
    
    d = content.find('p',class_="text-muted")
    certificate = d.find('span',class_='certificate')
    
    duration = d.find('span',class_='runtime')
    genre=d.find('span',class_='genre')
    genre=genre.text.split(",")
    
    if certificate:
        print(certificate.text)
        cf.append(certificate.text)
    
    print(duration.text)
    dr.append(duration.text)
    print(genre[0])
    g.append(genre[0])
    
    rating = content.find('strong')
    print(rating.text)
    rate.append(rating.text)
    
    c =content.find_all('p',class_='text-muted')
    description = c[1].text
    print(description)
    desc.append(description)
# Out:
# The Shawshank Redemption 1994 1
# A
# 142 min
#
# Drama
# 9.3
#
#     Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.
# The Godfather 1972 2
# A
# 175 min
#
# Crime
# 9.2
#
#     The aging patriarch of an organized crime dynasty transfers control of his clandestine empire to his reluctant son.
# The Dark Knight 2008 3
# UA
# 152 min
#
# Action
# 9.0
#
#     When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.
# The Godfather: Part II 1974 4
# A
# 202 min
#
# Crime
# 9.0
#
#     The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.
# The Lord of the Rings: The Return of the King 2003 5
# U
# 201 min
#
# Action
# 8.9
#
# ...

# %%
for link in links:
    page = requests.get(link)
    soup = BeautifulSoup(page.content,'html.parser')

    a = soup.find_all('div',class_='lister-item mode-advanced')
    
    for i in range(len(a)):
        
        content = a[i].find('div',class_='lister-item-content')
    
    
        text = content.find('a')
        n.append(text.text)
    
        year = content.find('span',class_='lister-item-year text-muted unbold')
        year = year.text.replace('(',"").replace(")","")
        y.append(year)
        rank = content.find('span',class_='lister-item-index unbold text-primary')
        rank = rank.text.replace('.',"")
        r.append(rank)
    
        print(text.text,year,rank)
    
    
    
        d = content.find('p',class_="text-muted")
        certificate = d.find('span',class_='certificate')
    
        duration = d.find('span',class_='runtime')
        genre=d.find('span',class_='genre')
        genre=genre.text.split(",")
    
        if certificate:
            print(certificate.text)
            cf.append(certificate.text)
    
        print(duration.text)
        dr.append(duration.text)
        print(genre[0])
        g.append(genre[0])
    
        rating = content.find('strong')
        print(rating.text)
        rate.append(rating.text)
    
        c =content.find_all('p',class_='text-muted')
        description = c[1].text
        print(description)
        desc.append(description)
# Out:
# Movie Number0
# The Shawshank Redemption 1994 1
# A
# 142 min
#
# Drama
# 9.3
#
#     Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.
# Movie Number1
# The Godfather 1972 2
# A
# 175 min
#
# Crime
# 9.2
#
#     The aging patriarch of an organized crime dynasty transfers control of his clandestine empire to his reluctant son.
# Movie Number2
# The Dark Knight 2008 3
# UA
# 152 min
#
# Action
# 9.0
#
#     When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.
# Movie Number3
# The Godfather: Part II 1974 4
# A
# 202 min
#
# Crime
# 9.0
#
#     The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.
# Movie Number4
# The Lord of the Rings: The Return of the King 2003 5
# U
# ...
